# %%
import pandas as pd
import numpy as np

# %% [markdown]
# <h1>Anime</h1>
# This dataset shows anime and their reccomendation scores based on the website MyAnimeList.net

# %%
df = pd.read_csv("anime.csv")
df
# Out:
#        MAL_ID                             Name    Score  \
# 0           1                     Cowboy Bebop     8.78
# 1           5  Cowboy Bebop: Tengoku no Tobira     8.39
# 2           6                           Trigun     8.24
# 3           7               Witch Hunter Robin     7.27
# 4           8                   Bouken Ou Beet     6.98
# ...       ...                              ...      ...
# 17557   48481  Daomu Biji Zhi Qinling Shen Shu  Unknown
# 17558   48483                     Mieruko-chan  Unknown
# 17559   48488  Higurashi no Naku Koro ni Sotsu  Unknown
# 17560   48491      Yama no Susume: Next Summit  Unknown
# 17561   48492                    Scarlet Nexus  Unknown
#
#                                                   Genres  \
# 0        Action, Adventure, Comedy, Drama, Sci-Fi, Space
# 1                  Action, Drama, Mystery, Sci-Fi, Space
# 2      Action, Sci-Fi, Adventure, Comedy, Drama, Shounen
# 3      Action, Mystery, Police, Supernatural, Drama, ...
# ...

# %%
df.loc[df['Name'].str.contains("Brotherhood")]
# Out:
#        MAL_ID                                               Name Score  \
# 3971     5114                   Fullmetal Alchemist: Brotherhood  9.19
# 4589     6421          Fullmetal Alchemist: Brotherhood Specials  8.03
# 5188     7902  Fullmetal Alchemist: Brotherhood - 4-Koma Theater  7.51
# 11698   33080                      Brotherhood: Final Fantasy XV  6.97
#
#                                                   Genres  \
# 3971   Action, Military, Adventure, Comedy, Drama, Ma...
# 4589   Military, Adventure, Drama, Magic, Fantasy, Sh...
# 5188                   Parody, Fantasy, Comedy, Military
# 11698                                             Action
#
#                                          English name  \
# 3971                  Fullmetal Alchemist:Brotherhood
# 4589   Fullmetal Alchemist:Brotherhood OVA Collection
# 5188   Fullmetal Alchemist:Brotherhood:4-Koma Theater
# 11698                                         Unknown
#
# ...
