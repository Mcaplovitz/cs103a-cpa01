# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# <h1>Anime</h1>
# This dataset shows anime and their reccomendation scores based on the website MyAnimeList.net aggregated until the year 2020.
#
# You can find this dataset by going to https://www.kaggle.com/hernan4444/anime-recommendation-database-2020 and clicking the download button on the "anime.csv" file.
#
# The two questions I have are:
#
#     1. What is the top rated anime?
#     2. What is the most watched & most dropped anime?

# %%
df = pd.read_csv("anime.csv", index_col=4)
df.index = np.where(df.index == 'Unknown', df['Name'], df.index)
df.describe()
# Out:
#              MAL_ID    Popularity       Members      Favorites       Watching  \
# count  17562.000000  17562.000000  1.756200e+04   17562.000000   17562.000000
# mean   21477.192347   8763.452340  3.465854e+04     457.746270    2231.487758
# std    14900.093170   5059.327278  1.252821e+05    4063.473313   14046.688133
# min        1.000000      0.000000  1.000000e+00       0.000000       0.000000
# 25%     5953.500000   4383.500000  3.360000e+02       0.000000      13.000000
# 50%    22820.000000   8762.500000  2.065000e+03       3.000000      73.000000
# 75%    35624.750000  13145.000000  1.322325e+04      31.000000     522.000000
# max    48492.000000  17565.000000  2.589552e+06  183914.000000  887333.000000
#
#           Completed        On-Hold        Dropped  Plan to Watch
# count  1.756200e+04   17562.000000   17562.000000   17562.000000
# mean   2.209557e+04     955.049653    1176.599533    8199.831227
# std    9.100919e+04    4275.675096    4740.348653   23777.691963
# ...

# %%
df.head(20)
# Out:
#                             MAL_ID                             Name Score  \
# Cowboy Bebop                     1                     Cowboy Bebop  8.78
# Cowboy Bebop:The Movie           5  Cowboy Bebop: Tengoku no Tobira  8.39
# Trigun                           6                           Trigun  8.24
# Witch Hunter Robin               7               Witch Hunter Robin  7.27
# Beet the Vandel Buster           8                   Bouken Ou Beet  6.98
# Eyeshield 21                    15                     Eyeshield 21  7.95
# Honey and Clover                16             Hachimitsu to Clover  8.06
# Hungry Heart: Wild Striker      17       Hungry Heart: Wild Striker  7.59
# Initial D Fourth Stage          18           Initial D Fourth Stage  8.15
# Monster                         19                          Monster  8.76
# Naruto                          20                           Naruto  7.91
# One Piece                       21                        One Piece  8.52
# ...

# %%
df.loc[df['Name'].str.contains("Brotherhood")]
# Out:
#                                                 MAL_ID  \
# Fullmetal Alchemist:Brotherhood                   5114
# Fullmetal Alchemist:Brotherhood OVA Collection    6421
# Fullmetal Alchemist:Brotherhood:4-Koma Theater    7902
# Brotherhood: Final Fantasy XV                    33080
#
#                                                                                              Name  \
# Fullmetal Alchemist:Brotherhood                                  Fullmetal Alchemist: Brotherhood
# Fullmetal Alchemist:Brotherhood OVA Collection          Fullmetal Alchemist: Brotherhood Specials
# Fullmetal Alchemist:Brotherhood:4-Koma Theater  Fullmetal Alchemist: Brotherhood - 4-Koma Theater
# Brotherhood: Final Fantasy XV                                       Brotherhood: Final Fantasy XV
#
#                                                 Score  \
# Fullmetal Alchemist:Brotherhood                  9.19
# Fullmetal Alchemist:Brotherhood OVA Collection   8.03
# ...

# %%
list(df.columns)
# Out:
# ['MAL_ID',
#  'Name',
#  'Score',
#  'Genres',
#  'Japanese name',
#  'Type',
#  'Episodes',
#  'Aired',
#  'Premiered',
#  'Producers',
#  'Licensors',
#  'Studios',
#  'Source',
#  'Duration',
#  'Rating',
#  'Ranked',
#  'Popularity',
#  'Members',
#  'Favorites',
#  'Watching',
#  'Completed',
#  'On-Hold',
#  'Dropped',
#  'Plan to Watch',
#  'Score-10',
#  'Score-9',
#  'Score-8',
#  'Score-7',
#  'Score-6',
#  'Score-5',
#  'Score-4',
#  'Score-3',
#  'Score-2',
#  'Score-1']

# %%
list(df.index)
# Out:
# ['Cowboy Bebop',
#  'Cowboy Bebop:The Movie',
#  'Trigun',
#  'Witch Hunter Robin',
#  'Beet the Vandel Buster',
#  'Eyeshield 21',
#  'Honey and Clover',
#  'Hungry Heart: Wild Striker',
#  'Initial D Fourth Stage',
#  'Monster',
#  'Naruto',
#  'One Piece',
#  'The Prince of Tennis',
#  'Ring ni Kakero 1',
#  'School Rumble',
#  'Desert Punk',
#  'Texhnolyze',
#  'Trinity Blood',
#  'Yakitate!! Japan',
#  'Zipang',
#  'Neon Genesis Evangelion',
#  'Neon Genesis Evangelion:Death & Rebirth',
#  'Neon Genesis Evangelion:The End of Evangelion',
#  'Berserk',
#  'Ghost in the Shell',
#  'Samurai X:Trust and Betrayal',
#  'Rurouni Kenshin',
#  'Samurai X:The Motion Picture',
#  'AKIRA',
#  '.hack//Sign',
#  'Oh! My Goddess',
#  'Ah! My Goddess',
#  'Angel Sanctuary',
#  'Battle Doll Angelic Layer',
#  'Ai Yori Aoshi',
#  'Appleseed (Movie)',
#  'Arc the Lad',
#  'Avenger',
#  'Beck:Mongolian Chop Squad',
#  'Blue Gender',
#  'Chobits',
#  'Chrono Crusade',
#  'D.N.Angel',
# ...

# %%
pd.pivot_table(data = df, index = ["Name"])
# Out:
#                                                     Completed  Dropped  \
# Name
# "0"                                                    2552.0     37.0
# "Aesop" no Ohanashi yori: Ushi to Kaeru, Yokuba...      124.0     74.0
# "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi             12789.0    104.0
# "Bungaku Shoujo" Memoire                              15648.0    372.0
# "Bungaku Shoujo" Movie                                31602.0    642.0
# ...                                                       ...      ...
# xxxHOLiC Rou                                          37721.0    433.0
# xxxHOLiC Shunmuki                                     41276.0    373.0
# Üks Uks                                                  53.0     43.0
# ēlDLIVE                                               18191.0   6919.0
# ◯                                                      1495.0     39.0
#
#                                                     Favorites  MAL_ID  \
# Name
# ...

# %%
df['Score'] = pd.to_numeric(df['Score'], errors = 'coerce')
sdf = df.sort_values('Score', ascending = False)
sdf = sdf[["Score", "Name"]].head(10)
# print(df.head(20).to_string(index=False))
# df.plot.bar(ylim = [0, 10])
plt.figure(figsize = (35,20))
plt.bar(sdf["Name"], sdf["Score"])
plt.xticks(rotation=0)
plt.ylim(8.8,9.2)
plt.xlabel('Anime Name')
plt.ylabel("Score")
for i in range(len(sdf["Name"])):
        plt.text(i, sdf["Score"][i], sdf["Score"][i], ha = 'center', size = 22)
plt.show()

# %%
pd.pivot_table(data = df, index = ["Name"])
# Out:
#                                                     Completed  Dropped  \
# Name
# "0"                                                    2552.0     37.0
# "Aesop" no Ohanashi yori: Ushi to Kaeru, Yokuba...      124.0     74.0
# "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi             12789.0    104.0
# "Bungaku Shoujo" Memoire                              15648.0    372.0
# "Bungaku Shoujo" Movie                                31602.0    642.0
# ...                                                       ...      ...
# xxxHOLiC Rou                                          37721.0    433.0
# xxxHOLiC Shunmuki                                     41276.0    373.0
# Üks Uks                                                  53.0     43.0
# ēlDLIVE                                               18191.0   6919.0
# ◯                                                      1495.0     39.0
#
#                                                     Favorites  MAL_ID  \
# Name
# ...

# %%
wdf = df
wdf["Watched"] = wdf['Completed'] + wdf['Watching']
wdf = wdf.sort_values('Watched', ascending = False)
wdf = wdf[["Watched", "Name"]].head(10)
# print(df.head(20).to_string(index=False))
# df.plot.bar(ylim = [0, 10])
plt.figure(figsize = (35,20))
plt.bar(wdf["Name"], wdf["Watched"])
plt.xticks(rotation=0)
for i in range(len(wdf["Name"])):
        plt.text(i, wdf["Watched"][i], wdf["Watched"][i], ha = 'center', size = 22)
plt.ylim(1200000,2500000)
plt.show()
